# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
GSE99738_mRNA = pd.read_csv('/Users/linze/PycharmProjects/untitled/datacleaning/GSE99738_mRNA.csv')

# %%
GSE99738_mRNA.fillna(value=np.nan, inplace=True)

# %%
GSE99738_mRNA=GSE99738_mRNA.set_index('GENE_SYMBOL')

# %%
GSE99738_mRNA=GSE99738_mRNA.drop('MAD',axis=1)
GSE99738_mRNA=GSE99738_mRNA.drop('variance',axis=1)
GSE99738_mRNA=GSE99738_mRNA.drop('Entropy',axis=1)

# %%
GSE99738_mRNA.columns
# Out:
# Index(['GSM2651032', 'GSM2651033', 'GSM2651034', 'GSM2651035', 'GSM2651036',
#        'GSM2651037', 'GSM2651038', 'GSM2651039', 'GSM2651040', 'GSM2651041',
#        'GSM2651042', 'GSM2651043', 'GSM2651044', 'GSM2651045', 'GSM2651046',
#        'GSM2651047'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(6,6))

# %%
ax=sns.heatmap(GSE99738_mRNA.head(), annot=True)

# %%
fig.savefig('heatmap_nocbar.png')
